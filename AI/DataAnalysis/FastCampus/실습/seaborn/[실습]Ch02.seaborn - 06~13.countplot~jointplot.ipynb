# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 한글 폰트 적용
plt.rc('font', family='NanumGothic') 
# 캔버스 사이즈 적용
plt.rcParams["figure.figsize"] = (12, 9)

# %% [markdown]
# ## 통계 기반의 시각화를 제공해주는 Seaborn

# %% [markdown]
# `seaborn` 라이브러리가 매력적인 이유는 바로 **통계 차트** 입니다.
#
# 이번 실습에서는 `seaborn`의 다양한 통계 차트 중 대표적인 차트 몇 개를 뽑아서 다뤄볼 예정입니다.
#
# 더 많은 통계 차트를 경험해보고 싶으신 분은 [공식 도큐먼트](https://seaborn.pydata.org/api.html)에서 확인하실 수 있습니다.

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# * survived: 생존여부
# * pclass: 좌석등급
# * sex: 성별
# * age: 나이
# * sibsp: 형제자매 + 배우자 숫자
# * parch: 부모자식 숫자
# * fare: 요금
# * embarked: 탑승 항구
# * class: 좌석등급 (영문)
# * who: 사람 구분
# * deck: 데크
# * embark_town: 탑승 항구 (영문)
# * alive: 생존여부 (영문)
# * alone: 혼자인지 여부

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# * total_bill: 총 합계 요금표
# * tip: 팁
# * sex: 성별
# * smoker: 흡연자 여부
# * day: 요일
# * time: 식사 시간
# * size: 식사 인원

# %% [markdown]
# ## 1. Countplot

# %% [markdown]
# 항목별 갯수를 세어주는 `countplot` 입니다.
#
# 알아서 해당 column을 구성하고 있는 value들을 구분하여 보여줍니다.

# %% [markdown]
# [countplot 공식 도큐먼트](https://seaborn.pydata.org/generated/seaborn.countplot.html)

# %%
# 배경을 darkgrid 로 설정
sns.set(style='darkgrid')

# %% [markdown]
# ### 1-1 세로로 그리기

# %%
sns.countplot(x="class",hue="who", data=titanic) # 코드를 입력해 주세요

plt.show()

# %% [markdown]
# ### 1-2. 가로로 그리기

# %%
sns.countplot(y="class",hue="who", data=titanic) # 코드를 입력해 주세요
plt.show()

# %% [markdown]
# ### 1-3. 색상 팔레트 설정

# %%
sns.countplot(x="class", hue="who", palette='copper', data=titanic)
plt.show()

# %% [markdown]
# ## 2. distplot

# %% [markdown]
# matplotlib의 `hist` 그래프와 `kdeplot`을 통합한 그래프 입니다.
#
# **분포**와 **밀도**를 확인할 수 있습니다.

# %% [markdown]
# [distplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.distplot.html?highlight=distplot#seaborn.distplot)

# %%
# 샘플데이터 생성
x = np.random.randn(100)
x
# Out:
# array([-0.41571232,  1.60658809, -1.46233074, -0.68676592,  1.21463554,
#        -0.77935004,  0.48338282,  0.29500281, -0.13398301,  0.90089149,
#         1.1749161 , -2.16061554, -1.21795734,  0.61494819,  1.57092362,
#        -0.74835471, -0.03491352,  0.45125308, -0.98346316,  0.48576515,
#         0.78520587, -0.77156861, -0.4328012 ,  0.51644833,  1.2475421 ,
#         0.62350193,  0.00327128, -0.16282159, -0.8659006 ,  1.10314088,
#         2.04056605, -0.24439901, -0.46444861, -1.0913386 ,  1.04298261,
#        -0.79243038,  0.84266236, -0.64474422,  0.8229543 ,  0.84376719,
#         0.17093788, -2.93841435, -0.27225556,  1.24230491,  0.79893209,
#         0.36186236,  0.81002963,  0.90800856, -0.07775959,  1.30916349,
#         0.58379362, -0.30277895,  0.83524809, -1.10831224,  0.44793956,
#        -0.3470687 , -0.92281428,  0.56712317,  1.17452953, -0.81719488,
#         0.75142441,  0.44569186, -0.24457996, -0.66628827,  2.50179109,
#        -1.64281006, -0.08607088,  0.46820956,  0.15230166,  0.18277958,
#        -0.71595777, -0.89607337, -0.54174949,  0.85857121, -1.07123917,
#         0.70346901,  0.55194463, -0.93259338, -0.56361773,  1.53245397,
#         1.20372512, -0.9751462 , -0.35113379,  0.13208123, -0.6198972 ,
#        -0.90959452,  0.49010287,  0.99220997, -0.92414496,  0.13547445,
#        -1.02617004, -0.30440664,  1.43009139, -0.61226733,  0.92430127,
#         1.11153738,  0.21316259, -0.87798374,  0.74667186,  0.51004297])

# %% [markdown]
# ### 2-1. 기본 distplot

# %%
sns.displot(x) # 코드를 입력해 주세요
plt.show()

# %% [markdown]
# ### 2-2. 데이터가 Series 일 경우

# %%
x = pd.Series(x, name="x variable")
x
# Out:
# 0    -0.415712
# 1     1.606588
# 2    -1.462331
# 3    -0.686766
# 4     1.214636
#         ...
# 95    1.111537
# 96    0.213163
# 97   -0.877984
# 98    0.746672
# 99    0.510043
# Name: x variable, Length: 100, dtype: float64

# %%
sns.distplot(x)
plt.show()
# Out:
# c:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 2-3. rugplot

# %% [markdown]
# `rug`는 `rugplot`이라고도 불리우며, 데이터 위치를 x축 위에 **작은 선분(rug)으로 나타내어 데이터들의 위치 및 분포**를 보여준다.

# %%
sns.distplot(x, rug=True, hist=False, kde=True) # 코드를 입력해 주세요

plt.show()
# Out:
# c:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# c:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 2-4. kde (kernel density)

# %% [markdown]
# `kde`는 histogram보다 **부드러운 형태의 분포 곡선**을 보여주는 방법

# %%
sns.distplot(x, rug=False, hist=False, kde=True) # 코드를 입력해 주세요

plt.show()
# Out:
# c:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 2-5. 가로로 표현하기

# %%
 sns.distplot(x, vertical=True) # 코드를 입력해 주세요
# Out:
# c:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Density', ylabel='x variable'>

# %% [markdown]
# ### 2-6. 컬러 바꾸기

# %%
sns.distplot(x, color="y")
plt.show()
# Out:
# c:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 3. heatmap

# %% [markdown]
# 색상으로 표현할 수 있는 다양한 정보를 **일정한 이미지위에 열분포 형태의 비쥬얼한 그래픽**으로
# 출력하는 것이 특징이다

# %% [markdown]
# [heatmap 도큐먼트](https://seaborn.pydata.org/generated/seaborn.heatmap.html?highlight=heatmap#seaborn.heatmap)

# %% [markdown]
# ### 3-1. 기본 heatmap

# %%
uniform_data = np.random.rand(10, 12)
sns.heatmap(uniform_data, annot=True) # 코드를 입력해 주세요

plt.show()

# %% [markdown]
# ### 3-2. pivot table을 활용하여 그리기

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pivot = tips.pivot_table(index='day', columns='size', values='tip')
pivot
# Out:
# size     1         2         3         4         5    6
# day
# Thur  1.83  2.442500  2.692500  4.218000  5.000000  5.3
# Fri   1.92  2.644375  3.000000  4.730000       NaN  NaN
# Sat   1.00  2.517547  3.797778  4.123846  3.000000  NaN
# Sun    NaN  2.816923  3.120667  4.087778  4.046667  5.0

# %%
sns.heatmap(pivot, annot=True, cmap='Blues') # 코드를 입력해 주세요

plt.show()

# %% [markdown]
# ### 3-3. correlation(상관관계)를 시각화

# %% [markdown]
# **corr()** 함수는 데이터의 상관관계를 보여줍니다.

# %%
titanic.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(titanic.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ## 4. pairplot

# %% [markdown]
# [pairplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.pairplot.html?highlight=pairplot#seaborn.pairplot)

# %% [markdown]
# pairplot은 그리도(grid) 형태로 각 **집합의 조합에 대해 히스토그램과 분포도**를 그립니다.
#
# 또한, 숫자형 column에 대해서만 그려줍니다.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### 4-1. 기본 pairplot 그리기

# %%
sns.pairplot(tips) # 코드를 입력해 주세요
plt.show()

# %% [markdown]
# ### 4-2. hue 옵션으로 특성 구분

# %%
sns.pairplot(tips, hue='size')
plt.show()

# %% [markdown]
# ### 4-3. 컬러 팔레트 적용

# %%
sns.pairplot(tips, hue='size', palette="rainbow")
plt.show()

# %% [markdown]
# ### 4-4. 사이즈 적용

# %%
sns.pairplot(tips, hue='size', palette="rainbow", height=5)
plt.show()

# %% [markdown]
# ## 5. violinplot

# %% [markdown]
# 바이올린처럼 생긴 violinplot 입니다.
#
# column에 대한 **데이터의 비교 분포도**를 확인할 수 있습니다.
#
# * 곡선진 부분 (뚱뚱한 부분)은 데이터의 분포를 나타냅니다.
# * 양쪽 끝 뾰족한 부분은 데이터의 최소값과 최대값을 나타냅니다.

# %% [markdown]
# [violinplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.violinplot.html)

# %% [markdown]
# ### 5-1. 기본 violinplot 그리기

# %%
sns.violinplot(x=tips["total_bill"]) # 코드를 입력해 주세요

plt.show()

# %% [markdown]
# ### 5-2. 비교 분포 확인

# %% [markdown]
# x, y축을 지정해줌으로썬 바이올린을 분할하여 **비교 분포**를 볼 수 있습니다.

# %%
sns.violinplot(x="day", y="total_bill", data=tips) # 코드를 입력해 주세요

plt.show()

# %% [markdown]
# ### 5-3. 가로로 뉘인 violinplot

# %%
sns.violinplot(x="total_bill", y="day", data=tips) # 코드를 입력해 주세요

plt.show()

# %% [markdown]
# ### 5-4. hue 옵션으로 분포 비교

# %% [markdown]
# 사실 hue 옵션을 사용하지 않으면 바이올린이 대칭이기 때문에 비교 분포의 큰 의미는 없습니다.
#
# 하지만, hue 옵션을 주면, **단일 column에 대한 바이올린 모양의 비교**를 할 수 있습니다.

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker", data=tips, palette="muted")
plt.show()

# %% [markdown]
# ### 5-5. split 옵션으로 바이올린을 합쳐서 볼 수 있습니다.

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue="smoker", palette="muted", split=True) # 코드를 입력해 주세요
plt.show()

# %% [markdown]
# ## 6. lmplot

# %% [markdown]
# `lmplot`은 column 간의 **선형관계를 확인하기에 용이한 차트**입니다.
#
# 또한, **outlier**도 같이 짐작해 볼 수 있습니다.

# %% [markdown]
# [lmplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.lmplot.html)

# %% [markdown]
# ### 6-1. 기본 lmplot

# %%
sns.lmplot(x="total_bill", y="tip", height=8, data=tips) # 코드를 입력해 주세요
plt.show()

# %% [markdown]
# ### 6-2. hue 옵션으로 다중 선형관계 그리기

# %% [markdown]
# 아래의 그래프를 통하여 비흡연자가, 흡연자 대비 좀 더 **가파른 선형관계**를 가지는 것을 볼 수 있습니다.

# %%
sns.lmplot(x="total_bill", y="tip", height=8, data=tips, hue="smoker") # 코드를 입력해 주세요

plt.show()

# %% [markdown]
# ### 6-3. col 옵션을 추가하여 그래프를 별도로 그려볼 수 있습니다

# %% [markdown]
# 또한, `col_wrap`으로 한 줄에 표기할 column의 갯수를 명시할 수 있습니다.

# %%
sns.lmplot(x="total_bill", y="tip",col="day",hue="smoker", height=6, data=tips, col_wrap=2) # 코드를 입력해 주세요
plt.show()

# %% [markdown]
# ## 7. relplot

# %% [markdown]
# 두 column간 상관관계를 보지만 `lmplot`처럼 선형관계를 따로 그려주지는 않습니다.

# %% [markdown]
# [relplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.relplot.html?highlight=relplot#seaborn.relplot)

# %% [markdown]
# ### 7-1. 기본 relplot

# %%
sns.relplot(x="total_bill", y="tip", hue="day", data=tips)
plt.show()

# %% [markdown]
# ### 7-2. col 옵션으로 그래프 분할

# %%
sns.relplot(x="total_bill", y="tip", hue="day", data=tips, col="time") # 코드를 입력해 주세요

plt.show()

# %% [markdown]
# ### 7-3. row와 column에 표기할 데이터 column 선택

# %%
sns.relplot(x="total_bill", y="tip", hue="day", row="sex", col="time", data=tips)
plt.show()

# %% [markdown]
# ### 7-4. 컬러 팔레트 적용

# %%
sns.relplot(x="total_bill", y="tip", hue="day", row="sex", col="time", palette='CMRmap_r', data=tips)
plt.show()

# %% [markdown]
# ## 8. jointplot

# %% [markdown]
# scatter(산점도)와 histogram(분포)을 동시에 그려줍니다.
#
# 숫자형 데이터만 표현 가능하니, 이 점 유의하세요.

# %% [markdown]
# [jointplot 도큐먼트](https://seaborn.pydata.org/generated/seaborn.jointplot.html?highlight=jointplot#seaborn.jointplot)

# %% [markdown]
# ### 8-1. 기본 jointplot 그리기

# %%
sns.jointplot(x="total_bill", y="tip", height=8, data=tips) # 코드를 입력해 주세요

plt.show()

# %% [markdown]
# ### 8-2. 선형관계를 표현하는 regression 라인 그리기

# %% [markdown]
# 옵션에 **kind='reg'**을 추가해 줍니다.

# %%
sns.jointplot("total_bill", "tip", height=8, data=tips, kind="reg")
plt.show()
# Out:
# c:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### 8-3. hex 밀도 보기

# %% [markdown]
# **kind='hex'** 옵션을 통해 hex 모양의 밀도를 확인할 수 있습니다.

# %%
sns.jointplot("total_bill", "tip", height=8, data=tips, kind="hex") # 코드를 입력해 주세요

plt.show()
# Out:
# c:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### 8-4. 등고선 모양으로 밀집도 확인하기

# %% [markdown]
# **kind='kde'** 옵션으로 데이터의 밀집도를 보다 부드러운 선으로 확인할 수 있습니ㅏ.

# %%
iris = sns.load_dataset('iris')
sns.jointplot("sepal_width", "petal_length", height=8, data=iris, kind="kde", color="g")
plt.show()
# Out:
# c:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
